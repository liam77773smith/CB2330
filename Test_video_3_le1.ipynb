# %% [markdown]
# <a href="https://colab.research.google.com/github/liam77773smith/CB2330/blob/main/Test_video_3_le1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello KTH")
# Out:
# Hello KTH
