# %% [markdown]
# <a href="https://colab.research.google.com/github/liam77773smith/CB2330/blob/test/Test_video_3_le1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))
if num > 5:
    print("you found a number greater than 5!")
elif num == 5:
  print("you got it just right!")
else:
    print("try again")
# Out:
# Enter a number: 3
# try again
